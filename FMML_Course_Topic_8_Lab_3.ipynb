# %% [markdown]
# <a href="https://colab.research.google.com/github/Tarshithreddy/FMML_COURSE_ASSIGNMENT/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# <table class="tfo-notebook-buttons" align="left">
#   <td>
#     <a target="_blank" href="https://colab.research.google.com/drive/1TuDbIyso6irdyBFgaHRpC-PxUICWPHcS?usp=sharing"><img height="32px" src="https://colab.research.google.com/img/colab_favicon.ico" />Run in Google Colab</a>
#   </td>
#   <td>
#     <a target="_blank" href="https://github.com/Foundations-in-Modern-Machine-Learning/course-contents/tree/main/Bayesian/"><img src="https://www.tensorflow.org/images/GitHub-Mark-32px.png" />View source on GitHub</a>
#   </td>
# </table>
# <br>
# <br>
# <br>

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2023-05-20 10:37:54--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   150MB/s    in 0.5s
#
# 2023-05-20 10:37:56 (150 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False), 
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split() 
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 14592  cs/0311033v1  We use the rank-frequency analysis for the est...    cs
# 1091   1706.06083v3  Recent work has demonstrated that neural netwo...  stat
# 40157  1712.04482v1  In this work, we conducted a survey on differe...    cs
# 30130  1711.07618v1  In this paper, we consider an interesting visi...    cs
# 13211   1304.4634v1  This paper presents a technique for reducing s...    cs
# ...             ...                                                ...   ...
# 11148   1410.4984v1  In this work, we present an extension of Gauss...    cs
# 39732  1703.02529v3  Recent advances in computer vision-in the form...    cs
# 6089   1607.01152v1  When sufficient labeled data are available, cl...  stat
# 18819   1208.3802v1  Today, we can find many search engines which p...    cs
# 1481   1608.08188v1  Visual question answering (VQA) systems are em...    cs
#
#                                                    title  year  \
# 14592  The Rank-Frequency Analysis for the Functional...  2003
# 1091   Towards Deep Learning Models Resistant to Adve...  2017
# 40157  Image Registration for the Alignment of Digiti...  2017
# 30130  $S^4$Net: Single Stage Salient-Instance Segmen...  2017
# 13211  Speckle Reduction in Polarimetric SAR Imagery ...  2013
# ...                                                  ...   ...
# 11148  Gaussian Process Models with Parallelization a...  2014
# 39732  NoScope: Optimizing Neural Network Queries ove...  2017
# 6089   How to Evaluate the Quality of Unsupervised An...  2016
# 18819         OntoAna: Domain Ontology for Human Anatomy  2012
# 1481   Visual Question: Predicting If a Crowd Will Ag...  2016
#
#                                                 keywords
# 14592  [frequency, estimation, vocabulary, ukrainian,...
# 1091   [demonstrated, vulnerable, adversarial, indist...
# 40157  [conducted, different, registration, algorithm...
# 30130  [interesting, segmentation, producing, approxi...
# 13211  [technique, polarimetric, synthetic, statistic...
# ...                                                  ...
# 11148  [extension, sophisticated, parallelization, ac...
# 39732  [increasing, inference, computationally, expen...
# 6089   [sufficient, available, classical, operating, ...
# 18819  [information, operational, information, troubl...
# 1481   [answering, examination, unavoidable, entangle...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 14592    [frequency, estimation, vocabulary, ukrainian,...
# 1091     [demonstrated, vulnerable, adversarial, indist...
# 40157    [conducted, different, registration, algorithm...
# 30130    [interesting, segmentation, producing, approxi...
# 13211    [technique, polarimetric, synthetic, statistic...
#                                ...
# 36727    [polyphonic, following, algorithm, following, ...
# 23023    [privileged, information, attractive, scenario...
# 36149    [relationships, variables, described, correspo...
# 11748    [generalized, regularization, technique, class...
# 15228    [simplification, grammatical, structural, comp...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]), 
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8743 words.
# Out of those 4530 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="6e4a8fb8-95fc-4ca7-9e1a-7171a2db385e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6e4a8fb8-95fc-4ca7-9e1a-7171a2db385e")) {                    Plotly.newPlot(                        "6e4a8fb8-95fc-4ca7-9e1a-7171a2db385e",                        [{"x":["functional","vocabulary","extrapolation","estimation","behaviour","frequency","principled","classified","important","adversaries","attacking","significantly","robustness","vulnerable","incorrectly","resistance","universal","existence","indistinguishable","guarantee","demonstrated","adversarial","particular","adversary","resistant","optimization","different","documents","suitability","acceptable","alignment","deformations","complexity","intensity","difficulties","algorithm","hyperspectral","transformation","application","investigated","spatially","performance","localized","information","digitized","stationary","registration","conducted","algorithms","similarity","distortions","historical","applications","evaluation","processing","outperforms","solutions","producing","development","available","facilitate","alternative","segmentation","understand","framework","surrounding","interesting","independent","benchmark","approximate","detection","resolution","trainable","functions","distinguish","instances","statistical","distributions","stochastic","objective","synthetic","distribution","simulated","therefore","technique","reduction","hypothesis","originated","divergences","preserves","distances","assessment","homogeneous","filtering","polarimetric","scattering","predicting","comparing","extracted","transactional","characterized","simulations","accomplished","variational","structure","discovering","generative","including","transactions","inference","discovered","discovery","membership","relations","facilitated","clusterings","boundaries","extraction","performed","comparative","occurrence","supervised","approaches","comparison","demonstrate","concentrate","comprehensive","regularizer","construct","experimental","superiority","perspectives","representations","probabilistic","correlations","graphical","multiscale","evaluated","importantly","appealing","formulate","occlusion","likelihood","conditional","representation","intercept","coordinate","processes","sequentially","following","architecture","computing","properties","intensive","introduces","literature","transform","appropriate","arbitrary","computation","computations","operations","arithmetic","introduced","posterior","averaging","specifically","simulates","perspective","hyperparameters","divergence","approximation","coefficient","accordingly","optimizes","parameters","minimizing","tractable","completeness","semantics","respected","accompanying","describes","attractive","techniques","parameter","introduce","typically","conditions","continuous","rademacher","separable","minimization","guarantees","optimistic","translates","achievable","generally","establish","empirical"],"y":[42,48,6,196,27,63,20,25,364,8,2,240,92,12,3,1,42,38,5,35,100,92,273,14,2,305,723,62,10,9,60,11,208,32,38,799,17,61,243,48,23,829,8,701,4,35,33,90,616,140,9,18,453,280,298,263,152,29,136,313,47,106,199,61,578,13,73,155,218,114,368,101,18,217,30,108,158,121,124,150,148,217,63,149,244,95,51,4,9,16,34,45,10,70,2,9,90,58,112,2,29,43,11,57,326,28,124,236,3,225,20,60,18,91,7,5,43,133,126,39,39,169,451,131,534,7,57,18,83,343,37,12,240,145,20,59,18,130,26,10,52,30,55,89,387,1,23,109,15,85,228,117,223,28,71,120,61,80,84,146,27,68,11,128,32,19,184,5,76,12,23,121,29,15,8,195,46,30,18,97,1,5,96,20,367,128,296,109,138,89,4,17,74,57,13,6,7,54,50,178],"type":"bar"},{"x":["functional","vocabulary","extrapolation","estimation","behaviour","frequency","principled","classified","important" ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4530,), (4530, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8208333333333333

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>A</span> <span style=''>semi</span> <span style='background-color:rgba(0, 255, 0, 0.5899581589958158);'>automatic</span> <span style=''>semantic</span> <span style=''>method</span> <span style=''>for</span> <span style=''>mapping</span> <span style=''>SNOMED</span> <span style=''>CT</span> <span style=''>concepts</span> <span style=''>to</span> <span style=''>VCM</span> <span style=''>Icons</span> <br/><br/><span style=''>VCM</span> <span style=''>(Visualization</span> <span style=''>of</span> <span style=''>Concept</span> <span style=''>in</span> <span style=''>Medicine)</span> <span style=''>is</span> <span style=''>an</span> <span style=''>iconic</span> <span style=''>language</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.47826086956521746);'>representing</span> <span style=''>key</span> <span style=''>medical</span> <span style=''>concepts</span> <span style=''>by</span> <span style=''>icons</span> <span style=''>However</span> <span style=''>the</span> <span style=''>use</span> <span style=''>of</span> <span style=''>this</span> <span style=''>language</span> <span style=''>with</span> <span style='background-color:rgba(0, 255, 0, 0.5072463768115942);'>reference</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>terminologies</span> <span style=''>such</span> <span style=''>as</span> <span style=''>SNOMED</span> <span style=''>CT</span> <span style=''>will</span> <span style=''>require</span> <span style=''>the</span> <span style=''>mapping</span> <span style=''>of</span> <span style=''>its</span> <span style=''>icons</span> <span style=''>to</span> <span style=''>the</span> <span style=''>terms</span> <span style=''>of</span> <span style=''>these</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>terminologies</span> <span style=''>Here</span> <span style=''>we</span> <span style=''>present</span> <span style=''>and</span> <span style=''>evaluate</span> <span style=''>a</span> <span style=''>semi</span> <span style='background-color:rgba(0, 255, 0, 0.5899581589958158);'>automatic</span> <span style=''>semantic</span> <span style=''>method</span> <span style=''>for</span> <span style=''>the</span> <span style=''>mapping</span> <span style=''>of</span> <span style=''>SNOMED</span> <span style=''>CT</span> <span style=''>concepts</span> <span style=''>to</span> <span style=''>VCM</span> <span style=''>icons</span> <span style=''>Both</span> <span style=''>SNOMED</span> <span style=''>CT</span> <span style=''>and</span> <span style=''>VCM</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.5714285714285714);'>compositional</span> <span style=''>in</span> <span style=''>nature</span> <span style=''>SNOMED</span> <span style=''>CT</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>expressed</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.4666666666666666);'>description</span> <span style=''>logic</span> <span style=''>and</span> <span style=''>VCM</span> <span style='background-color:rgba(0, 255, 0, 0.94);'>semantics</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.33333333333333337);'>formalized</span> <span style=''>in</span> <span style=''>an</span> <span style=''>OWL</span> <span style=''>ontology</span> <span style=''>The</span> <span style=''>proposed</span> <span style=''>method</span> <span style=''>involves</span> <span style=''>the</span> <span style=''>manual</span> <span style=''>mapping</span> <span style=''>of</span> <span style=''>a</span> <span style=''>limited</span> <span style=''>number</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>underlying</span> <span style=''>concepts</span> <span style=''>from</span> <span style=''>the</span> <span style=''>VCM</span> <span style=''>ontology</span> <span style=''>followed</span> <span style=''>by</span> <span style='background-color:rgba(0 ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Additive</span> <span style=''>Kernels</span> <span style=''>for</span> <span style=''>Gaussian</span> <span style=''>Process</span> <span style=''>Modeling</span> <br/><br/><span style=''>Gaussian</span> <span style=''>Process</span> <span style=''>(GP)</span> <span style=''>models</span> <span style=''>are</span> <span style=''>often</span> <span style=''>used</span> <span style=''>as</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>mathematical</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approximations</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>computationally</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>expensive</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>experiments</span> <span style=''>Provided</span> <span style=''>that</span> <span style=''>its</span> <span style=''>kernel</span> <span style=''>is</span> <span style=''>suitably</span> <span style=''>chosen</span> <span style=''>and</span> <span style=''>that</span> <span style=''>enough</span> <span style=''>data</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>available</span> <span style=''>to</span> <span style=''>obtain</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>reasonable</span> <span style=''>fit</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>simulator</span> <span style=''>a</span> <span style=''>GP</span> <span style=''>model</span> <span style=''>can</span> <span style=''>beneficially</span> <span style=''>be</span> <span style=''>used</span> <span style=''>for</span> <span style=''>tasks</span> <span style=''>such</span> <span style=''>as</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>prediction</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>optimization</span> <span style=''>or</span> <span style=''>Monte</span> <span style=''>Carlo</span> <span style=''>based</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>quantification</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>uncertainty</span> <span style=''>However</span> <span style=''>the</span> <span style=''>former</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>conditions</span> <span style=''>become</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>unrealistic</span> <span style=''>when</span> <span style=''>using</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classical</span> <span style=''>GPs</span> <span style=''>as</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimension</span> <span style=''>of</span> <span style=''>input</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>increases</span> <span style=''>One</span> <span style=''>popular</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>alternative</span> <span style=''>is</span> <span style=''>then</span> <span style=''>to</span> <span style=''>turn</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Generalized</span> <span style=''>Additive</span> <span style=''>Models</span> <span style=''>(GAMs)</span> <span style=''>relying</span> <span style=''>on</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>assumption</span> <span style=''>that</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>simulators</span> <span style=''>response</span> <span style=''>can</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>approximately</span> <span style=''>be</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>decomposed</span> <span style=''>as</span> <span style=''>a</span> <span style=''>sum</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>univariate</span> <span style='background-color:rgba ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Training</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Conditional</span> <span style=''>Random</span> <span style=''>Fields</span> <span style=''>with</span> <span style=''>Natural</span> <span style=''>Gradient</span> <span style=''>Descent</span> <br/><br/><span style=''>We</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>novel</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>parameter</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>estimation</span> <span style='background-color:rgba(255, 0, 0, 0.3120567375886525);'>procedure</span> <span style=''>that</span> <span style=''>works</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>efficiently</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>conditional</span> <span style=''>random</span> <span style=''>fields</span> <span style=''>(CRF)</span> <span style=''>This</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>is</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>extension</span> <span style=''>to</span> <span style=''>the</span> <span style=''>maximum</span> <span style='background-color:rgba(255, 0, 0, 0.5473251028806585);'>likelihood</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>estimation</span> <span style=''>(MLE)</span> <span style=''>using</span> <span style=''>loss</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>functions</span> <span style=''>defined</span> <span style=''>by</span> <span style=''>Bregman</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>divergences</span> <span style=''>which</span> <span style=''>measure</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>proximity</span> <span style=''>between</span> <span style=''>the</span> <span style=''>model</span> <span style='background-color:rgba(255, 0, 0, 0.4444444444444444);'>expectation</span> <span style=''>and</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>empirical</span> <span style=''>mean</span> <span style=''>of</span> <span style=''>the</span> <span style=''>feature</span> <span style=''>vectors</span> <span style=''>This</span> <span style=''>leads</span> <span style=''>to</span> <span style=''>a</span> <span style=''>flexible</span> <span style=''>training</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>framework</span> <span style=''>from</span> <span style=''>which</span> <span style=''>multiple</span> <span style=''>update</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>strategies</span> <span style=''>can</span> <span style=''>be</span> <span style=''>derived</span> <span style=''>using</span> <span style=''>natural</span> <span style=''>gradient</span> <span style=''>descent</span> <span style=''>(NGD)</span> <span style=''>We</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>carefully</span> <span style=''>choose</span> <span style=''>the</span> <span style=''>convex</span> <span style=''>function</span> <span style=''>inducing</span> <span style=''>the</span> <span style=''>Bregman</span> <span style='background-color:rgba(255, 0, 0, 0.45238095238095233);'>divergence</span> <span style=''>so</span> <span style=''>that</span> <span style=''>the</span> <span style=''>types</span> <span style=''>of</span> <span style=''>updates</span> <span style=''>are</span> <span style=''>reduced</span> <span style=''>while</span> <span style=''>making</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimization</span> <span style='background-color:rgba(255, 0, 0, 0.3120567375886525);'>procedure</span> <span style=''>more</span> <span style='background-color:rgba(0, 255, 0, 0.3013333333333333);'>effective</span> <span style=''>by</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>transforming</span> <span style=''> ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Variance</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Regularizing</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Adversarial</span> <span style=''>Learning</span> <br/><br/><span style=''>We</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>introduce</span> <span style=''>a</span> <span style=''>novel</span> <span style=''>approach</span> <span style=''>for</span> <span style=''>training</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>adversarial</span> <span style=''>models</span> <span style=''>by</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>replacing</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>discriminator</span> <span style=''>score</span> <span style=''>with</span> <span style=''>a</span> <span style=''>bi</span> <span style=''>modal</span> <span style=''>Gaussian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distribution</span> <span style=''>over</span> <span style=''>the</span> <span style=''>realfake</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>indicator</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>variables</span> <span style=''>In</span> <span style=''>order</span> <span style=''>to</span> <span style=''>do</span> <span style=''>this</span> <span style=''>we</span> <span style=''>train</span> <span style=''>the</span> <span style=''>Gaussian</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classifier</span> <span style=''>to</span> <span style=''>match</span> <span style=''>the</span> <span style=''>target</span> <span style=''>bi</span> <span style=''>modal</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distribution</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>implicitly</span> <span style=''>through</span> <span style=''>meta</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>adversarial</span> <span style=''>training</span> <span style=''>We</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>hypothesize</span> <span style=''>that</span> <span style=''>this</span> <span style=''>approach</span> <span style=''>ensures</span> <span style=''>a</span> <span style=''>non</span> <span style=''>zero</span> <span style=''>gradient</span> <span style=''>to</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>generator</span> <span style=''>even</span> <span style=''>in</span> <span style=''>the</span> <span style=''>limit</span> <span style=''>of</span> <span style=''>a</span> <span style=''>perfect</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classifier</span> <span style=''>We</span> <span style=''>test</span> <span style=''>our</span> <span style=''>method</span> <span style=''>against</span> <span style=''>standard</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>benchmark</span> <span style=''>image</span> <span style=''>datasets</span> <span style=''>as</span> <span style=''>well</span> <span style=''>as</span> <span style=''>show</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classifier</span> <span style=''>output</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distribution</span> <span style=''>is</span> <span style=''>smooth</span> <span style=''>and</span> <span style=''>has</span> <span style=''>overlap</span> <span style=''>between</span> <span style=''>the</span> <span style=''>real</span> <span style=''>and</span> <span style=''>fake</span> <span style=''>modes</span> <br/><br/>

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	architecture (0.08169115012540308)
# 	knowledge (0.1254030813328556)
# 	processing (0.10677176639197421)
# 	segmentation (0.07130060910068076)
# 	information (0.2511644571838051)
# 	representation (0.13865997850232892)
# 	different (0.2590469365818703)
# 	detection (0.13185238265854532)
# 	convolutional (0.13185238265854532)
# 	recognition (0.13543532783948406)
#
# Some Statistics words are:
# 	optimization (0.18914883026381285)
# 	stochastic (0.1329019412643106)
# 	theoretical (0.14982578397212543)
# 	statistical (0.15729218516674962)
# 	estimation (0.1717272274763564)
# 	distribution (0.18964659034345446)
# 	algorithm (0.399701343952215)
# 	dimensional (0.187655550024888)
# 	inference (0.20109507217521155)
# 	regression (0.187655550024888)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]), 
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="e3dc3b21-b095-47fc-9aad-163ad157ae48" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e3dc3b21-b095-47fc-9aad-163ad157ae48")) {                    Plotly.newPlot(                        "e3dc3b21-b095-47fc-9aad-163ad157ae48",                        [{"x":["functional","vocabulary","extrapolation","estimation","behaviour","frequency","principled","classified","important","adversaries","attacking","significantly","robustness","vulnerable","incorrectly","resistance","universal","existence","indistinguishable","guarantee","demonstrated","adversarial","particular","adversary","resistant","optimization","different","documents","suitability","acceptable","alignment","deformations","complexity","intensity","difficulties","algorithm","hyperspectral","transformation","application","investigated","spatially","performance","localized","information","digitized","stationary","registration","conducted","algorithms","similarity","distortions","historical","applications","evaluation","processing","outperforms","solutions","producing","development","available","facilitate","alternative","segmentation","understand","framework","surrounding","interesting","independent","benchmark","approximate","detection","resolution","trainable","functions","distinguish","instances","statistical","distributions","stochastic","objective","synthetic","distribution","simulated","therefore","technique","reduction","hypothesis","originated","divergences","preserves","distances","assessment","homogeneous","filtering","polarimetric","scattering","predicting","comparing","extracted","transactional","characterized","simulations","accomplished","variational","structure","discovering","generative","including","transactions","inference","discovered","discovery","membership","relations","facilitated","clusterings","boundaries","extraction","performed","comparative","occurrence","supervised","approaches","comparison","demonstrate","concentrate","comprehensive","regularizer","construct","experimental","superiority","perspectives","representations","probabilistic","correlations","graphical","multiscale","evaluated","importantly","appealing","formulate","occlusion","likelihood","conditional","representation","intercept","coordinate","processes","sequentially","following","architecture","computing","properties","intensive","introduces","literature","transform","appropriate","arbitrary","computation","computations","operations","arithmetic","introduced","posterior","averaging","specifically","simulates","perspective","hyperparameters","divergence","approximation","coefficient","accordingly","optimizes","parameters","minimizing","tractable","completeness","semantics","respected","accompanying","describes","attractive","techniques","parameter","introduce","typically","conditions","continuous","rademacher","separable","minimization","guarantees","optimistic","translates","achievable","generally","establish","empirical","implementation","crowdsourced","achieving","representative","sensitive","experiments","efficiency","addressing","objectives","algorithmic","remarkable","differential","manageable","shortcomings","selection","discriminators","statistic","diversity","extensive","categorization","classifiers","comparable","infrastructure","architectures","researchers","geospatial","understanding","expensive","benchmarks","worldwide","neighborhoods","availability","convolutional","vegetation","furthermore","environments","supervision","environment","investment","classification","satellite","carefully","developing","transition","partially","interactions","specified","efficiently","sequential","alternatives","represent","cooperative","observable","compactly","uncertainty","dependencies","transitio ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	homoscedastic
# 	multiarmed
# 	misspecified
# 	selectors
# 	covariances
# 	changepoints
# 	missforest
# 	transcriptional
# 	forecasters
# 	retention
# 	changepoint
# 	retrospective
# 	tractography
# 	cytometry
# 	portfolios
# 	fundamentals
# 	detectability
# 	autocorrelation
# 	predetermined
# 	advection
# Some words which never appear in Statistics papers:
# 	digitized
# 	unsolvable
# 	formalisms
# 	disjunction
# 	logically
# 	treebanks
# 	monolingual
# 	automaton
# 	panchromatic
# 	manipulation
# 	bibliographic
# 	transposed
# 	transposition
# 	obfuscation
# 	authorship
# 	occlusions
# 	colorization
# 	telecommunication
# 	devnagari
# 	devanagari

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.0826140567200985e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7641666666666667
